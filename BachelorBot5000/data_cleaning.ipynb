# %%
# Import dependencies
import pandas as pd

# %%
# Read in csv file
df = pd.read_csv('resources/historical_data.csv')

# %%
# Use the unnamed: 0 column as the placement for contestants
df = df.rename(columns={'Unnamed: 0': 'result'})
df['result'] = 1 + df['result']

# %%
# Merge the data in the Job and Occupation columns
df['Occupation'] = df['Occupation'].fillna(df['Job'])

df.head()
# Out:
#    result             Name   Age              Hometown  \
# 0       1     Amanda Marsh  23.0       Chanute, Kansas
# 1       2      Trista Rehn  29.0   St. Louis, Missouri
# 2       3   Shannon Oliver  24.0         Dallas, Texas
# 3       4  Kimberly Karels  24.0        Tempe, Arizona
# 4       5     Cathy Grimes  22.0  Terre Haute, Indiana
#
#                                Job Eliminated  season  \
# 0                    Event Planner     Winner       1
# 1                Miami Heat Dancer  Runner-up       1
# 2  Financial Management Consultant     Week 5       1
# 3                            Nanny     Week 4       1
# 4                 Graduate Student     Week 3       1
#
#                         Occupation Outcome Place  Ref Arrived
# 0                    Event Planner     NaN   NaN  NaN     NaN
# 1                Miami Heat Dancer     NaN   NaN  NaN     NaN
# 2  Financial Management Consultant     NaN   NaN  NaN     NaN
# 3                            Nanny     NaN   NaN  NaN     NaN
# 4                 Graduate Student     NaN   NaN  NaN     NaN

# %%
# Drop unnecessary columns
df = df[['Name', 'Age', 'season', 'Hometown', 'Occupation', 'result']]
df = df.rename(columns={'Name': 'name',
                        'Age': 'age',
                        'Hometown': 'hometown',
                        'Occupation': 'occupation'})

# Investigate the dataset to see what dtypes need to be converted
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        612 non-null    object
#  1   age         611 non-null    object
#  2   season      612 non-null    int64
#  3   hometown    612 non-null    object
#  4   occupation  612 non-null    object
#  5   result      612 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 28.8+ KB

# %%
# Convert the datatypes
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['season'] = df['season'].astype(str)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        612 non-null    object
#  1   age         608 non-null    float64
#  2   season      612 non-null    object
#  3   hometown    612 non-null    object
#  4   occupation  612 non-null    object
#  5   result      612 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 28.8+ KB

# %%
# Investigate the increase in NULL values for Age
null_df = df[df['age'].isna()]

null_df
# Out:
#                  name  age season                   hometown  \
# 42     Cosetta Blanca  NaN      9                      Italy
# 408     Maquel Cooper  NaN     22  (Returned to competition)
# 439  Alayah Benavidez  NaN     24  (Returned to competition)
# 494       Susie Evans  NaN     26  (Returned to competition)
#
#                     occupation  result
# 42                      Dancer      18
# 408  (Returned to competition)      16
# 439  (Returned to competition)      17
# 494  (Returned to competition)       4

# %%
# These are duplicates and can be dropped
# Minus Cosetta (sorry)
df = df.dropna()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 608 entries, 0 to 611
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        608 non-null    object
#  1   age         608 non-null    float64
#  2   season      608 non-null    object
#  3   hometown    608 non-null    object
#  4   occupation  608 non-null    object
#  5   result      608 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 33.2+ KB

# %%
# Remove the number link references
pattern = r'\[\d+\]'
df['name'] = df['name'].str.replace(pattern, '')
# Out:
# C:\Users\grant\AppData\Local\Temp\ipykernel_5592\3063554193.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['name'] = df['name'].str.replace(pattern, '')
#                          name   age season                    hometown  \
# 0                Amanda Marsh  23.0      1             Chanute, Kansas
# 1                 Trista Rehn  29.0      1         St. Louis, Missouri
# 2              Shannon Oliver  24.0      1               Dallas, Texas
# 3             Kimberly Karels  24.0      1              Tempe, Arizona
# 4                Cathy Grimes  22.0      1        Terre Haute, Indiana
# ..                        ...   ...    ...                         ...
# 607               Erin Landry  28.0     23                Plano, Texas
# 608  Adrianne "Jane" Averbukh  26.0     23  West Hollywood, California
# 609           Laura Pellerito  26.0     23               Dallas, Texas
# 610              Revian Chang  24.0     23                Plano, Texas
# 611          Tahzjuan Hawkins  25.0     23      Castle Pines, Colorado
#
#                           occupation  result
# 0                      Event Planner       1
# 1                  Miami Heat Dancer       2
# 2    Financial Management Consultant       3
# 3                              Nanny       4
# 4                   Graduate Student       5
# ..                               ...     ...
# 607                       Cinderella      26
# 608                    Social Worker      27
# 609                       Accountant      28
# 610                            Nurse      29
# 611   Business Development Associate      30
#
# [608 rows x 6 columns]

# %%
# Split the hometown into two additional columns for city and state
df[['city', 'state', 'other']] = df['hometown'].str.split(',', expand=True)
# Out:
#               name   age season              hometown  \
# 0     Amanda Marsh  23.0      1       Chanute, Kansas
# 1      Trista Rehn  29.0      1   St. Louis, Missouri
# 2   Shannon Oliver  24.0      1         Dallas, Texas
# 3  Kimberly Karels  24.0      1        Tempe, Arizona
# 4     Cathy Grimes  22.0      1  Terre Haute, Indiana
#
#                         occupation  result         city      state other
# 0                    Event Planner       1      Chanute     Kansas  None
# 1                Miami Heat Dancer       2    St. Louis   Missouri  None
# 2  Financial Management Consultant       3       Dallas      Texas  None
# 3                            Nanny       4        Tempe    Arizona  None
# 4                 Graduate Student       5  Terre Haute    Indiana  None

# %%
# Replace values in city with Chicago and state with Illinois
df.at[37, 'hometown'] = 'Chicago, Illinois'
df.at[37, 'city'] = 'Chicago'
df.at[37, 'state'] = 'Illinois'

# %%
# Drop the other column
df.drop(columns='other', inplace=True)

# %%
# Split the name column similar to the hometown
df[['first', 'x', 'last']] = df['name'].str.split(' ', expand=True)

# %%
# Find all the nicknames
df['last'] = df['last'].fillna(df['x'])
df.drop(columns='x', inplace=True)

# %%
# Print out list of occupations for later grouping
occupations = df['occupation']

occupations.to_csv('x.csv')

# Used Excel to analyze the professions and create categories

# Read in csv file
profession_groups_df = pd.read_csv('resources/professions.csv')

# %%
# Merge the dataframes for professional groups
final_df = pd.merge(df, profession_groups_df, on='occupation', how='inner')

# Drop duplicates based on all columns
final_df = final_df.drop_duplicates().reset_index()

# Format Final columns
final_df = final_df[['name', 'age', 'season', 'hometown', 'occupation', 'result',
       'city', 'state', 'first', 'last', 'job_category']]

# %%
# Export to csv in the resources folder
final_df.to_csv('resources/dataset.csv')
