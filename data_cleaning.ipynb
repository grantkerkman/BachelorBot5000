# %%
# Import dependencies
import pandas as pd

# %%
# Read in csv file
df = pd.read_csv('resources/historical_data.csv')

# Use the unnamed: 0 column as the placement for contestants
df = df.rename(columns={'Unnamed: 0': 'result'})

# %%
# Merge the data in the Job and Occupation columns
df['Occupation'] = df['Occupation'].fillna(df['Job'])

df.head()
# Out:
#    result             Name   Age              Hometown  \
# 0       0     Amanda Marsh  23.0       Chanute, Kansas
# 1       1      Trista Rehn  29.0   St. Louis, Missouri
# 2       2   Shannon Oliver  24.0         Dallas, Texas
# 3       3  Kimberly Karels  24.0        Tempe, Arizona
# 4       4     Cathy Grimes  22.0  Terre Haute, Indiana
#
#                                Job Eliminated  season  \
# 0                    Event Planner     Winner       1
# 1                Miami Heat Dancer  Runner-up       1
# 2  Financial Management Consultant     Week 5       1
# 3                            Nanny     Week 4       1
# 4                 Graduate Student     Week 3       1
#
#                         Occupation Outcome Place  Ref Arrived
# 0                    Event Planner     NaN   NaN  NaN     NaN
# 1                Miami Heat Dancer     NaN   NaN  NaN     NaN
# 2  Financial Management Consultant     NaN   NaN  NaN     NaN
# 3                            Nanny     NaN   NaN  NaN     NaN
# 4                 Graduate Student     NaN   NaN  NaN     NaN

# %%
# Drop unnecessary columns
df = df[['Name', 'Age', 'season', 'Hometown', 'Occupation', 'result']]
df = df.rename(columns={'Name': 'name',
                        'Age': 'age',
                        'Hometown': 'hometown',
                        'Occupation': 'occupation'})

# Investigate the dataset to see what dtypes need to be converted
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        612 non-null    object
#  1   age         611 non-null    object
#  2   season      612 non-null    int64
#  3   hometown    612 non-null    object
#  4   occupation  612 non-null    object
#  5   result      612 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 28.8+ KB

# %%
# Convert the datatypes
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['season'] = df['season'].astype(str)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        612 non-null    object
#  1   age         608 non-null    float64
#  2   season      612 non-null    object
#  3   hometown    612 non-null    object
#  4   occupation  612 non-null    object
#  5   result      612 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 28.8+ KB

# %%
# Investigate the increase in NULL values for Age
null_df = df[df['age'].isna()]

null_df
# Out:
#                  name  age season                   hometown  \
# 42     Cosetta Blanca  NaN      9                      Italy
# 408     Maquel Cooper  NaN     22  (Returned to competition)
# 439  Alayah Benavidez  NaN     24  (Returned to competition)
# 494       Susie Evans  NaN     26  (Returned to competition)
#
#                     occupation  result
# 42                      Dancer      17
# 408  (Returned to competition)      15
# 439  (Returned to competition)      16
# 494  (Returned to competition)       3

# %%
# These are duplicates and can be dropped
# Minus Cosetta (sorry)
df = df.dropna()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 608 entries, 0 to 611
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        608 non-null    object
#  1   age         608 non-null    float64
#  2   season      608 non-null    object
#  3   hometown    608 non-null    object
#  4   occupation  608 non-null    object
#  5   result      608 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage:
# 43            Elyse Hammer  27.0      9      Meadow Vista, California
# 44           Heather Sneed  34.0      9       Aliquippa, Pennsylvania
# 45          Jessica Horner  25.0      9     Charlotte, North Carolina
# 46            Laura Morgan  29.0      9     Spring Valley, California
# 47       Meryl "Meri" Barr  27.0      9           Biloxi, Mississippi
# 48             Renée Snell  30.0      9           Baltimore, Maryland
# 49             Rita Ghazal  29.0      9            Richmond, Virginia
# 50          Rosella Fratto  27.0      9          Homer Glen, Illinois
#
#                          occupation  result
# 0                     Event Planner       0
# 1                 Miami Heat Dancer       1
# 2   Financial Management Consultant       2
# 3                             Nanny       3
# 4                  Graduate Student       4
# 5                          Attorney       5
# 6                           Actress       6
# 7      Commercial Real Estate Agent       7
# 8               Special Ed. Teacher       8
# 9            Production Coordinator       9
# 10                 Hooters Waitress      10
# 11                          Actress      11
# 12            Power Tool Sales Rep.      12
# 13                     Photographer      13
# 14                 Graduate Student      14
# 15    Business Development Director      15
# 16                Neuropsychologist      16
# 17                           Doctor      17
# 18                      Bar Manager      18
# 19                   Retail Manager      19
# 20            Advertising Executive      20
# 21                         Attorney      21
# 22         Insurance Representative      22
# 23                6th Grade Teacher      23
# 24            Technology Specialist      24
# 25                          Teacher       0
# 26                        Publicist       1
# 27                Marketing manager       2
# 28                          Student       3
# 29                          Realtor       4
# 30                          Teacher       5
# 31                         Attorney       6
# 32            Ultrasound technician       7
# 33                    Event planner       8
# 34                          Realtor       9
# 35                Interior designer      10
# 36                       Journalist      11
# 37                            Model      12
# 38                  Hotel concierge      13
# 39                     Beer chemist      14
# 40                         Attorney      15
# 41                     Restaurateur      16
# 43                        Physician      18
# 44                 Registered nurse      19
# 45                  Assistant buyer      20
# 46                  Dolphin trainer      21
# 47                         Attorney      22
# 48               Broadcast marketer      23
# 49                   Policy advisor      24
# 50                   Make-up artist      25

# %%
# Remove the number link references
pattern = r'\[\d+\]'
df['name'] = df['name'].str.replace(pattern, '')

df
# Out:
# C:\Users\grant\AppData\Local\Temp\ipykernel_9844\3063554193.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['name'] = df['name'].str.replace(pattern, '')
#                          name   age season                    hometown  \
# 0                Amanda Marsh  23.0      1             Chanute, Kansas
# 1                 Trista Rehn  29.0      1         St. Louis, Missouri
# 2              Shannon Oliver  24.0      1               Dallas, Texas
# 3             Kimberly Karels  24.0      1              Tempe, Arizona
# 4                Cathy Grimes  22.0      1        Terre Haute, Indiana
# ..                        ...   ...    ...                         ...
# 607               Erin Landry  28.0     23                Plano, Texas
# 608  Adrianne "Jane" Averbukh  26.0     23  West Hollywood, California
# 609           Laura Pellerito  26.0     23               Dallas, Texas
# 610              Revian Chang  24.0     23                Plano, Texas
# 611          Tahzjuan Hawkins  25.0     23      Castle Pines, Colorado
#
#                           occupation  result
# 0                      Event Planner       0
# 1                  Miami Heat Dancer       1
# 2    Financial Management Consultant       2
# 3                              Nanny       3
# 4                   Graduate Student       4
# ..                               ...     ...
# 607                       Cinderella      25
# 608                    Social Worker      26
# 609                       Accountant      27
# 610                            Nurse      28
# 611   Business Development Associate      29
#
# [608 rows x 6 columns]

# %%
# Split the hometown into two additional columns for city and state
df[['city', 'state', 'other']] = df['hometown'].str.split(',', expand=True)

df.head()
# Out:
#               name   age season              hometown  \
# 0     Amanda Marsh  23.0      1       Chanute, Kansas
# 1      Trista Rehn  29.0      1   St. Louis, Missouri
# 2   Shannon Oliver  24.0      1         Dallas, Texas
# 3  Kimberly Karels  24.0      1        Tempe, Arizona
# 4     Cathy Grimes  22.0      1  Terre Haute, Indiana
#
#                         occupation  result         city      state other
# 0                    Event Planner       0      Chanute     Kansas  None
# 1                Miami Heat Dancer       1    St. Louis   Missouri  None
# 2  Financial Management Consultant       2       Dallas      Texas  None
# 3                            Nanny       3        Tempe    Arizona  None
# 4                 Graduate Student       4  Terre Haute    Indiana  None

# %%
# Inspectthe unique instances in other
df['other'].unique()

# Create DataFrame to view other data
x = df.loc[df['other'] ==' Illinois']

x
# Out:
#             name   age season                      hometown occupation  \
# 37  April Jacobs  23.0      9  Hyde Park, Chicago, Illinois      Model
#
#     result       city     state      other
# 37      12  Hyde Park   Chicago   Illinois

# %%
# Replace values in city with Chicago and state with Illinois
df.at[37, 'hometown'] = 'Chicago, Illinois'
df.at[37, 'city'] = 'Chicago'
df.at[37, 'state'] = 'Illinois'

# %%
# Drop the other column
df.drop(columns='other', inplace=True)

# %%
# Split the name column similar to the hometown
df[['first', 'x', 'last']] = df['name'].str.split(' ', expand=True)

# %%
# Find all the nicknames
df['last'] = df['last'].fillna(df['x'])
df.drop(columns='x', inplace=True)

# %%
# Preview the DataFrame
df.head()
# Out:
#               name   age season              hometown  \
# 0     Amanda Marsh  23.0      1       Chanute, Kansas
# 1      Trista Rehn  29.0      1   St. Louis, Missouri
# 2   Shannon Oliver  24.0      1         Dallas, Texas
# 3  Kimberly Karels  24.0      1        Tempe, Arizona
# 4     Cathy Grimes  22.0      1  Terre Haute, Indiana
#
#                         occupation  result         city      state     first  \
# 0                    Event Planner       0      Chanute     Kansas    Amanda
# 1                Miami Heat Dancer       1    St. Louis   Missouri    Trista
# 2  Financial Management Consultant       2       Dallas      Texas   Shannon
# 3                            Nanny       3        Tempe    Arizona  Kimberly
# 4                 Graduate Student       4  Terre Haute    Indiana     Cathy
#
#      last
# 0   Marsh
# 1    Rehn
# 2  Oliver
# 3  Karels
# 4  Grimes
